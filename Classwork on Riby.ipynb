# %%
import pandas as pd
import numpy as np

# %%
riby =pd.read_csv(r"C:\Users\SLEEK\Downloads\Riby Data Set.csv")

# %%
riby
# Out:
#                               Region           Country        Item Type  \
# 0                 Sub-Saharan Africa      South Africa           Fruits
# 1       Middle East and North Africa           Morocco          Clothes
# 2              Australia and Oceania  Papua New Guinea             Meat
# 3                 Sub-Saharan Africa          Djibouti          Clothes
# 4                             Europe          Slovakia        Beverages
# ...                              ...               ...              ...
# 499995                          Asia           Myanmar           Fruits
# 499996         Australia and Oceania       New Zealand  Office Supplies
# 499997                        Europe         Lithuania           Snacks
# 499998                          Asia          Malaysia        Beverages
# 499999                        Europe          Slovakia        Household
#
#        Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %% [raw]
# Questions
# 1. How to get the total profit in a region
# 2. Total unit sold
# 3. Highest unit sold
# 4. profit for each region

# %%
# 1. How to get the total profit in a region
riby.groupby("Region")["Total Profit"].sum()
# Out:
# Region
# Asia                                 2.859312e+10
# Australia and Oceania                1.593599e+10
# Central America and the Caribbean    2.124888e+10
# Europe                               5.062910e+10
# Middle East and North Africa         2.435939e+10
# North America                        4.272509e+09
# Sub-Saharan Africa                   5.120098e+10
# Name: Total Profit, dtype: float64

# %%
# another method for question 1
riby.groupby("Region").agg({"Total Profit": "sum"})
# Out:
#                                    Total Profit
# Region
# Asia                               2.859312e+10
# Australia and Oceania              1.593599e+10
# Central America and the Caribbean  2.124888e+10
# Europe                             5.062910e+10
# Middle East and North Africa       2.435939e+10
# North America                      4.272509e+09
# Sub-Saharan Africa                 5.120098e+10

# %%
riby.groupby("Region").agg({"Total Profit": sum})
# Out:
#                                    Total Profit
# Region
# Asia                               2.859312e+10
# Australia and Oceania              1.593599e+10
# Central America and the Caribbean  2.124888e+10
# Europe                             5.062910e+10
# Middle East and North Africa       2.435939e+10
# North America                      4.272509e+09
# Sub-Saharan Africa                 5.120098e+10

# %%
# find Europe shipping date
riby.iloc[[2,5],7:]
# Out:
#     Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 2  06/04/2015         360      421.89     364.69      151880.40   131288.40
# 5  12/18/2011        1379        9.33       6.92       12866.07     9542.68
#
#    Total Profit
# 2      20592.00
# 5       3323.39

# %%
riby.iloc[[5,7,9,10],[2,5,7]]
# Out:
#     Item Type  Order Date   Ship Date
# 5      Fruits  11/07/2011  12/18/2011
# 7   Beverages  11/30/2016   1/16/2017
# 9   Cosmetics   5/23/2016   5/24/2016
# 10     Fruits  02/09/2014   2/23/2014

# %%
#Last five
riby.iloc[-5:,[2,5,7]]
# Out:
#               Item Type Order Date   Ship Date
# 499995           Fruits  1/16/2015   2/18/2015
# 499996  Office Supplies  1/22/2011  02/01/2011
# 499997           Snacks  1/25/2017   1/26/2017
# 499998        Beverages  3/13/2016   3/18/2016
# 499999        Household  5/13/2015  06/12/2015

# %%
#first 5
riby.iloc[:5,[2,5,7]]
# Out:
#    Item Type  Order Date   Ship Date
# 0     Fruits   7/27/2012   7/28/2012
# 1    Clothes   9/14/2013  10/19/2013
# 2       Meat   5/15/2015  06/04/2015
# 3    Clothes   5/17/2017  07/02/2017
# 4  Beverages  10/26/2016  12/04/2016

# %%
#first 5 Region and country
riby.iloc[:5,[0,1]]
# Out:
#                          Region           Country
# 0            Sub-Saharan Africa      South Africa
# 1  Middle East and North Africa           Morocco
# 2         Australia and Oceania  Papua New Guinea
# 3            Sub-Saharan Africa          Djibouti
# 4                        Europe          Slovakia

# %%
riby.iloc[:5,[0,1]]
region= riby.iloc[:5,[0,1]]
region.sort_values(by=["Region"],ascending=False)
# ,inplace=True; is to save it
# Out:
#                          Region           Country
# 0            Sub-Saharan Africa      South Africa
# 3            Sub-Saharan Africa          Djibouti
# 1  Middle East and North Africa           Morocco
# 4                        Europe          Slovakia
# 2         Australia and Oceania  Papua New Guinea

# %%
region
# Out:
#                          Region           Country
# 0            Sub-Saharan Africa      South Africa
# 1  Middle East and North Africa           Morocco
# 2         Australia and Oceania  Papua New Guinea
# 3            Sub-Saharan Africa          Djibouti
# 4                        Europe          Slovakia

# %%
riby.sort_values("Region",ascending= False)
# Out:
#                     Region       Country  Item Type Sales Channel  \
# 0       Sub-Saharan Africa  South Africa     Fruits       Offline
# 125824  Sub-Saharan Africa       Senegal  Baby Food        Online
# 125812  Sub-Saharan Africa      Ethiopia       Meat        Online
# 125815  Sub-Saharan Africa       Liberia     Cereal        Online
# 125816  Sub-Saharan Africa  South Africa       Meat        Online
# ...                    ...           ...        ...           ...
# 107548                Asia    Bangladesh     Cereal        Online
# 107554                Asia      Thailand  Household       Offline
# 292307                Asia    Uzbekistan     Snacks       Offline
# 403790                Asia     Indonesia       Meat        Online
# 233930                Asia         Nepal  Cosmetics       Offline
#
#        Order Priority  Order Date   Order ID   Ship Date  Units Sold  \
# 0                   M   7/27/2012  443368995   7/28/2012        1593
# ...

# %%
riby2= riby.sort_values(["Region"],ascending= False)

# %%
#Total cost of the first 10 region 
riby.loc[:10,["Region", "Total Cost"]]
# Out:
#                           Region  Total Cost
# 0             Sub-Saharan Africa    11023.56
# 1   Middle East and North Africa   165258.24
# 2          Australia and Oceania   131288.40
# 3             Sub-Saharan Africa    20142.08
# 4                         Europe   126301.67
# 5                           Asia     9542.68
# 6             Sub-Saharan Africa    18978.63
# 7             Sub-Saharan Africa    46922.04
# 8             Sub-Saharan Africa   470364.16
# 9             Sub-Saharan Africa  2045547.44
# 10                          Asia    55595.28

# %%
#Total Cost of all the regions
riby.groupby("Region").agg({"Total Cost": sum})
# Out:
#                                      Total Cost
# Region
# Asia                               6.822308e+10
# Australia and Oceania              3.801209e+10
# Central America and the Caribbean  5.073529e+10
# Europe                             1.209122e+11
# Middle East and North Africa       5.828618e+10
# North America                      1.028004e+10
# Sub-Saharan Africa                 1.223593e+11

# %%
#Total Cost of Sub-saharan Africa
agg = riby.groupby("Region").agg({"Total Cost": sum})
agg.iloc[-1]
# Out:
# Total Cost    1.223593e+11
# Name: Sub-Saharan Africa, dtype: float64

# %%
#Total revenue of a country
riby.groupby("Country").agg({"Total Revenue": sum})
# Out:
#               Total Revenue
# Country
# Afghanistan    3.558434e+09
# Albania        3.591588e+09
# Algeria        3.578638e+09
# Andorra        3.440316e+09
# Angola         3.497485e+09
# ...                     ...
# Vatican City   3.495584e+09
# Vietnam        3.546793e+09
# Yemen          3.764892e+09
# Zambia         3.536644e+09
# Zimbabwe       3.569856e+09
#
# [185 rows x 1 columns]

# %%
#Country with highest total revenue
country = riby.groupby("Country").agg({"Total Revenue": sum})
# Out:
# Country
# Afghanistan     3.558434e+09
# Albania         3.591588e+09
# Algeria         3.578638e+09
# Andorra         3.440316e+09
# Angola          3.497485e+09
#                     ...
# Vatican City    3.495584e+09
# Vietnam         3.546793e+09
# Yemen           3.764892e+09
# Zambia          3.536644e+09
# Zimbabwe        3.569856e+09
# Length: 185, dtype: float64

# %%
#Country with highest Total Revenue
country.sort_values(["Total Revenue"],ascending= False).head(1)
# Out:
#          Total Revenue
# Country
# Rwanda    3.822950e+09

# %%
#Country with lowest Total Revenue
country.sort_values(["Total Revenue"],ascending= True).head(1)
# Out:
#          Total Revenue
# Country
# Iran      3.314763e+09
